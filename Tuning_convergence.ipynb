# %%
import pandas as pd
import numpy as np
from dataloading import DataLoader
from eda_py import EDA
from eALS_adaptor import eALSAdaptor
from implicit.evaluation import train_test_split, ranking_metrics_at_k
from cv_py import CrossValidation
from visualize_py import Visualize
import matplotlib.pyplot as plt

# %cd C:\Users\781110104\OneDrive - Genpact\Documents\VSCode
# Out:
# C:\Users\781110104\OneDrive - Genpact\Documents\VSCode

# %%
hyper_ials = pd.read_csv('curves_ials.csv')
hyper_ials_t = pd.read_csv('curves_ials_t.csv')
hyper_eals_t = pd.read_csv('curves_eals.csv')
hyper_bpr = pd.read_csv('curves_bpr.csv')
hyper_lmf = pd.read_csv('curves_lmf.csv')

# %%
hyper_ials_add = pd.read_csv('curves_ials_add.csv')
hyper_ials_t_add = pd.read_csv('curves_ials_t_add.csv')
hyper_eals_t_add = pd.read_csv('curves_eals_add.csv')
hyper_bpr_add = pd.read_csv('curves_bpr_add.csv')
hyper_lmf_add = pd.read_csv('curves_lmf_add.csv')

# %%
hyper_ials_complete = pd.concat([hyper_ials, hyper_ials_add], axis=0)
hyper_ials_t_complete = pd.concat([hyper_ials_t, hyper_ials_t_add], axis=0)
hyper_eals_t_complete = pd.concat([hyper_eals_t, hyper_eals_t_add], axis=0)
hyper_bpr_complete = pd.concat([hyper_bpr, hyper_bpr_add], axis=0)
hyper_lmf_complete = pd.concat([hyper_lmf, hyper_lmf_add], axis=0)

# %%
vis = Visualize(style='science')

# %%
# arguments: results frame over iterations+factors tuning. save=False per default, can be set to True. Will be saved as curves.pdf
vis.get_convergence_curves(hyper_lmf_complete, save=True)

# %% [markdown]
# Source code for get_convergence_curves() method:

# %%
file = hyper_ials_complete
p_df = file.pivot(index='iterations', columns='factors', values='precision')
map_df = file.pivot(index='iterations', columns='factors', values='map')
ndcg_df = file.pivot(index='iterations', columns='factors', values='ndcg')
mpr_df = file.pivot(index='iterations', columns='factors', values='mpr')
data_df = [p_df, map_df, ndcg_df, mpr_df]
names = ['P@10', 'MAP@10', 'NDCG@10', 'MPR']
loc = ['lower right', 'lower right', 'lower right', 'upper right']

fig, ax = plt.subplots(figsize=(17, 15), nrows=2, ncols=2)
plt.subplots_adjust(wspace=0.2, hspace=0.3, right=0.82)
c = 0
for i in range(2):
    for j in range(2):
        data_filtered = data_df[c].loc[4:, [10, 50, 100, 150, 200]]
        ax[i,j].plot(data_filtered, linestyle='-', marker='o', linewidth=2)
        ax[i,j].set_title(names[c], fontsize=30)
        ax[i,j].set_xlabel('Iterations', fontsize=25)
        ax[i,j].tick_params(axis='both', which='major', labelsize=17)
        ax[i,j].tick_params(axis='both', which='minor', labelsize=17)
        ax[i,j].autoscale()
        ax[i,j].grid(linestyle=':')
        c += 1
fig.legend(data_filtered.columns, loc='center right', ncol=1, title='Factors',fancybox=True, shadow=False, frameon=True, title_fontsize=25, fontsize=20,
bbox_to_anchor=(0.94, 0.79))
#plt.savefig('curves_eals.pdf')
plt.show()
