# %%
import pandas as pd
import numpy as np

# %%
# %cd C:\Users\781110104\OneDrive - Genpact\Documents\VSCode
# Out:
# C:\Users\781110104\OneDrive - Genpact\Documents\VSCode

# %%
hyper_als_t = pd.read_csv('terex_ials.csv')
hyper_als_a = pd.read_csv('agco_ials.csv')

hyper_bpr_t = pd.read_csv('terex_bpr.csv')
hyper_bpr_a = pd.read_csv('agco_bpr.csv')

hyper_eals_t = pd.read_csv('terex_eals.csv')
hyper_eals_a = pd.read_csv('agco_eals.csv')

# %%
from visualize_py import Visualize

# %%
hyper_als_t
# Out:
#      Unnamed: 0  factors  regularization  alpha  iterations  precision  \
# 0             0       64            0.01   0.05          15   0.108718
# 1             1       64            0.01   0.10          15   0.130256
# 2             2       64            0.01   0.20          15   0.171795
# 3             3       64            0.01   0.30          15   0.200513
# 4             4       64            0.01   0.50          15   0.228718
# ..          ...      ...             ...    ...         ...        ...
# 163         163       64           70.00   5.00          15   0.466667
# 164         164       64           70.00  10.00          15   0.448718
# 165         165       64           70.00  15.00          15   0.449231
# 166         166       64           70.00  20.00          15   0.442564
# 167         167       64           70.00  30.00          15   0.432821
#
#           map      ndcg       auc       mpr
# 0    0.056879  0.116742  0.504168  0.443152
# ...

# %%
vis = Visualize()

# %%
vis.get_heatmap(hyper_als_a, 'iALS', 'map')

# %%
vis.get_heatmap(hyper_bpr_a, 'BPR', 'mpr')

# %%
vis.get_heatmap(hyper_eals_a[hyper_eals_a.alpha == 0.75], 'eALS', 'mpr')
